# %%
#Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Importing dataset from csv to data frame
visual_data = pd.read_csv('machine_learning_set.csv')

# %%
visual_data
# Out:
#       daily_non_vehicle_traffic  avg_temp_f_daily  total_rain_mm_daily  \
# 0                           837         57.984797                 0.00
# 1                          1266         69.329005                 0.00
# 2                           935         69.509291                 0.00
# 3                          1328         73.245192                 0.00
# 4                          1260         78.542579                 0.00
# ...                         ...               ...                  ...
# 1194                       1612         51.522502                 0.25
# 1195                       1342         55.695496                 0.50
# 1196                       1330         47.189002                 0.00
# 1197                        903         40.782499                 0.25
# 1198                        777         47.692254                 0.25
#
#       total_snow_mm_daily  avg_cloud_percent_daily  \
# 0                     0.0                92.000000
# ...

# %%
#Exploring daily_non_vehicle_traffic on holidays
holidays = visual_data.loc[visual_data.holiday != 'none']
plt.figure(figsize=(10,8))
sns.boxplot(y='holiday',x='daily_non_vehicle_traffic', data = holidays)
plt.show()

# %%
#Exploring daily_non_vehicle_traffic on holidays
holidays = visual_data.loc[visual_data.holiday != 'none']
plt.figure(figsize=(10,8))
sns.barplot(y='holiday',x='daily_non_vehicle_traffic', data = holidays)
plt.show()

# %%
#Exploring total_vehicle_volume_daily on holidays
holidays = visual_data.loc[visual_data.holiday != 'none']
plt.figure(figsize=(10,8))
sns.boxplot(y='holiday',x='total_vehicle_volume_daily', data = holidays)
plt.show()

# %%
#Exploring total_vehicle_volume_daily on holidays
holidays = visual_data.loc[visual_data.holiday != 'none']
plt.figure(figsize=(10,8))
sns.barplot(y='holiday',x='total_vehicle_volume_daily', data = holidays)
plt.show()

# %%
#Plotting total_vehicle_volume_daily over month
plt.figure(figsize=(18,12))
sns.barplot(x='month', y = 'total_vehicle_volume_daily', data = visual_data)
plt.show()

# %%
#Plotting daily_non_vehicle_traffic over month
plt.figure(figsize=(18,12))
sns.barplot(x='month', y = 'daily_non_vehicle_traffic', data = visual_data)
plt.show()

# %%
#total_vehicle_volume_daily plotted against weekday. 
plt.figure(figsize=(12,10))
sns.boxplot(x='day_of_week', y='total_vehicle_volume_daily', data = visual_data)
plt.show()

# %%
#total_vehicle_volume_daily plotted against weekday. 
plt.figure(figsize=(12,10))
sns.barplot(x='day_of_week', y='total_vehicle_volume_daily', data = visual_data)
plt.show()

# %%
#daily_non_vehicle_traffic plotted against weekday. 
plt.figure(figsize=(12,10))
sns.boxplot(x='day_of_week', y='daily_non_vehicle_traffic', data = visual_data)
plt.show()

# %%
#daily_non_vehicle_traffic plotted against weekday. 
plt.figure(figsize=(12,10))
sns.barplot(x='day_of_week', y='daily_non_vehicle_traffic', data = visual_data)
plt.show()

# %%
#Exploring avg_temp_f_daily on month
plt.figure(figsize=(12,10))
sns.barplot(y='avg_temp_f_daily',x='month', data = visual_data)
plt.show()

# %%
#aggreagating total_vehicle_volume_daily over month and plotting 

visual_data_line = visual_data.groupby('month').aggregate({'total_vehicle_volume_daily':'mean'})
plt.figure(figsize=(12,10))
sns.lineplot(x = visual_data_line.index, y = visual_data_line.total_vehicle_volume_daily, data = visual_data_line)
plt.show()

# %%
#aggreagating daily_non_vehicle_traffic over month and plotting 

visual_data_line2 = visual_data.groupby('month').aggregate({'daily_non_vehicle_traffic':'mean'})
plt.figure(figsize=(12,10))
sns.lineplot(x = visual_data_line2.index, y = visual_data_line2.daily_non_vehicle_traffic, data = visual_data_line2)
plt.show()

# %%
sns.regplot(x="total_vehicle_volume_daily", y="avg_temp_f_daily", data=visual_data)
# Out:
# <AxesSubplot:xlabel='total_vehicle_volume_daily', ylabel='avg_temp_f_daily'>

# %%
sns.lmplot(x="total_vehicle_volume_daily", y="avg_temp_f_daily", col="day_of_week", data=visual_data,
           aspect=1);

# %%
sns.lmplot(x="daily_non_vehicle_traffic", y="avg_temp_f_daily", col="day_of_week", data=visual_data,
           aspect=1);

# %%
sns.catplot(x="day_of_week", y="daily_non_vehicle_traffic", kind="swarm", data=visual_data)
# Out:
# C:\Users\vandi\anaconda3\envs\PythonData\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 18.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\vandi\anaconda3\envs\PythonData\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 13.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\vandi\anaconda3\envs\PythonData\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 15.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\vandi\anaconda3\envs\PythonData\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 17.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
sns.catplot(x="day_of_week", y="total_vehicle_volume_daily", kind="swarm", data=visual_data)
# Out:
# C:\Users\vandi\anaconda3\envs\PythonData\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 39.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\vandi\anaconda3\envs\PythonData\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 37.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\vandi\anaconda3\envs\PythonData\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 40.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\vandi\anaconda3\envs\PythonData\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 42.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...
